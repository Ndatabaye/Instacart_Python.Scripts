# %% [markdown]
# # Import Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Data

# %%
#Defining path
path=r'/Users/guillaumemac/06-2023 Instacart Basket Analysis'

# %%
#Importing Data
ords_prods_merge=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods.pkl'))

# %%
#Checking the data shape
ords_prods_merge.shape
# Out:
# (32404859, 17)

# %%
#Checking the data output
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# # Question 2

# %%
#Creating a subset of the data
df=ords_prods_merge[:1000000]

# %%
#Aggregated mean of the “order_number” column grouped by “department_id” for a subset of the dataframe
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
#Aggregated mean of the “order_number” column grouped by “department_id” for the entire dataframe
ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Question 3

# %% [markdown]
# ## Using the entire to get the agg mean allows us to view the mean value of all the departments whilst using the subset dataframe only show few departments.

# %% [markdown]
# # Question 4

# %%
#Creating a loyalty flag for existing customers
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Telling the dsiplay function display to remove a limit on rows shown
pd.options.display.max_rows = None

# %%
#Checking for data output
ords_prods_merge.head(150)
# Out:
#      order_id  user_id  order_number  orders_day_of_the_week  \
# 0     2539329        1             1                       2
# 1     2398795        1             2                       3
# 2      473747        1             3                       3
# 3     2254736        1             4                       4
# 4      431534        1             5                       4
# 5     3367565        1             6                       2
# 6      550135        1             7                       1
# 7     3108588        1             8                       1
# 8     2295261        1             9                       1
# 9     2550362        1            10                       4
# 10    2968173       15            15                       1
# 11    1870022       15            17                       2
# 12    1911383       15            18                       2
# 13    2715276       15            21                       1
# ...

# %%
# Create flags to assign "loyalty" labels to user_id based on max_order value
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Checking for loyalty flags for accuracy
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# # Question 5

# %%
#Finding the agg mean value of product price by loyalty group
#Grouping by prices
ords_prods_merge.groupby('prices')
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
#Descriptive statistics for the prices column
ords_prods_merge['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %% [markdown]
# # Question 6

# %% [markdown]
# # Creating flags to assign "spending" labels to users based on the  mean product price

# %%
# Group data by "user_id" column, generate mean product price for each user, create "mean_price" for aggregation results
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#Checking data output
ords_prods_merge.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
#Creating Low Spender label
ords_prods_merge.loc[ords_prods_merge['mean_price'] >= 10, 'spending_flag'] = 'High Spender'

# %%
#Creating High Spender Label
ords_prods_merge.loc[ords_prods_merge['mean_price']<10,'spending_flag']='Low Spender'

# %%
# Checking the new spending flags for accuracy
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low Spender     31770614
# High Spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# # Question 7

# %% [markdown]
# ### Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

# %%
#Create a frequency flag using groupings
ords_prods_merge['median_days'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#checking the data output
ords_prods_merge.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices  _merge    price_range_loc  Busiest days  \
# ...

# %%
# Create flags to assign freqency labels to users based on median days since prior order
ords_prods_merge.loc[ords_prods_merge['median_days'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days'] > 10) & (ords_prods_merge['median_days'] <= 20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Checking spending flags for accuracy
ords_prods_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: frequency_flag, dtype: int64

# %%
#Investigating the null values
ords_prods_merge[ords_prods_merge.frequency_flag.isnull()]
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 13645692    895835   159838             1                       0
# 17251990    895835   159838             1                       0
# 17622767    895835   159838             1                       0
# 24138593    895835   159838             1                       0
# 25880002    895835   159838             1                       0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 13645692                 17                     NaN       10749
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 24138593                 17                     NaN       21334
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# ...

# %% [markdown]
# # Observation: The null values are believed to be from a new customer without days_since_prior_order data. therefore opting to leave it untouched as it is also too little to affect my analysis moving forward

# %%
# Exporting dataframe as pkl file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'new_ords_prods.pkl'))
