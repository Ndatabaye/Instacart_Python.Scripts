# %% [markdown]
# # 01 Importing Libraries

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Dataframes

# %%
# Defining Path
path=r'/Users/guillaumemac/06-2023 Instacart Basket Analysis'

# %%
#Importing orders_products_combined pickle file
df_ords_prods_combined=pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_combined.pkl'))

# %%
#Checking the shape
df_ords_prods_combined.shape
# Out:
# (32434489, 11)

# %%
#Checking the output
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0           0   2539329        1             1                       2
# 1           0   2539329        1             1                       2
# 2           0   2539329        1             1                       2
# 3           0   2539329        1             1                       2
# 4           0   2539329        1             1                       2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
#Importing products_checked dataset
df_prods=pd.read_csv(os.path.join(path,'02 Data','Prepared Data','products_checked.csv'),index_col=False)

# %%
#checking the shape
df_prods.shape
# Out:
# (49672, 6)

# %%
#Checking the output
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# # Merging Dataframes

# %%
df_merged= df_ords_prods_combined.merge(df_prods, on = 'product_id')

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_the_week  \
# 0             0   2539329        1             1                       2
# 1             1   2398795        1             2                       3
# 2             2    473747        1             3                       3
# 3             3   2254736        1             4                       4
# 4             4    431534        1             5                       4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %% [markdown]
# # Dropping existing column without overwriting the data

# %%
#Dropping the previously created _merged column in the orders_product_combined.pkl to be able to create a new one that will allow me to confirm the new merge results
df_ords_prods_new=df_ords_prods_combined.drop('_merge',axis=1)

# %%
df_merged = df_ords_prods_new.merge(df_prods, on = ('product_id'), indicator = True)

# %%
df_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_the_week  \
# 0             0   2539329        1             1                       2
# 1             1   2398795        1             2                       3
# 2             2    473747        1             3                       3
# 3             3   2254736        1             4                       4
# 4             4    431534        1             5                       4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
#Dropping the unnamed column
df_merged=df_merged.drop(columns=['Unnamed: 0_x','Unnamed: 0_y'])

# %%
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged.shape
# Out:
# (32404859, 14)

# %%
df_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# # Exporting the New Dataframe as a pickle file

# %%
# Export data to pkl
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
