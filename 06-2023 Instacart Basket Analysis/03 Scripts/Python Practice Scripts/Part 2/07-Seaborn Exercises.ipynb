# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Seaborn Exercises
#
# Time to practice your new seaborn skills! Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises. Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.jointplot(x='fare', y='age', data = titanic)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
sns.displot(titanic['fare'], color='red', bins=40)

# %% [markdown]
# # ANSWER

# %%
sns.displot(titanic['fare'], color='red', bins=30, kde=False)
plt.xlim(0,600)
# Out:
# (0.0, 600.0)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %% [markdown]
# # ANSWER

# %% [markdown]
# ### I couldn't change the colors to match the plot below

# %%
sns.set_style("whitegrid")
sns.boxplot (x='class',y='age', data = titanic)
plt.ylim(0,80)
# Out:
# (0.0, 80.0)

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %% [markdown]
# # ANSWER

# %%
sns.set_style("whitegrid")
sns. swarmplot (x='class', y= 'age', data=titanic, marker='o' ,s=4, palette= 'Set2')
# Out:
# /var/folders/wm/drxqc4897cz5y2338pz0stxm0000gn/T/ipykernel_1336/1140586458.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns. swarmplot (x='class', y= 'age', data=titanic, marker='o' ,s=4, palette= 'Set2')
# <Axes: xlabel='class', ylabel='age'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %% [markdown]
# # ANSWER

# %%
sns.countplot(data = titanic,x ='sex', palette=['b', 'g'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %% [markdown]
# # ANSWER

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm',annot=True,fmt=".1f",cbar=True,linewidth=0.5)
# Out:
# /var/folders/wm/drxqc4897cz5y2338pz0stxm0000gn/T/ipykernel_1336/3020115906.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr(),cmap='coolwarm',annot=True,fmt=".1f",cbar=True,linewidth=0.5)
# <Axes: >

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %% [markdown]
# # ANSWER

# %% [markdown]
# ### I wasn't able to set the bin size for the X axis at a 10 interval as it is in your plot.

# %%
grid=sns.FacetGrid(titanic, col='sex')
grid.map(sns.histplot,'age',bins=10,color='black')

# %% [markdown]
# # Great Job!
#
# ### That is it for now! We'll see a lot more of seaborn practice problems in the machine learning section!
